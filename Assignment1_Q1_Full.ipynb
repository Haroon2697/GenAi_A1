# %% [markdown]
# <a href="https://colab.research.google.com/github/Haroon2697/GenAi_A1/blob/main/Assignment1_Q1_Full.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1. Setup — Kaggle credentials

# %%
import os
from google.colab import userdata

# SECURITY: don't hardcode API tokens in the notebook.
# In Colab, click the key icon (Secrets) in the left sidebar, add a secret
# named KAGGLE_API_TOKEN with your (rotated) Kaggle token as the value,
# then enable notebook access for it.
os.environ['KAGGLE_API_TOKEN'] = userdata.get('KAGGLE_API_TOKEN')
# !pip install -q kaggle

# %% [markdown]
# ## 2. Download raw dataset

# %%
# !kaggle datasets download -d paultimothymooney/chest-xray-pneumonia -p /content/data
# !unzip -q /content/data/chest-xray-pneumonia.zip -d /content/data
# Out:
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2)
# Dataset URL: https://www.kaggle.com/datasets/paultimothymooney/chest-xray-pneumonia
# License(s): other
# Downloading chest-xray-pneumonia.zip to /content/data
# 100% 2.29G/2.29G [00:22<00:00, 111MB/s]

# %%
# !pip install -q imagehash
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.7/296.7 kB 10.4 MB/s eta 0:00:00

# %% [markdown]
# ## 3. Preprocessing — inspect, deduplicate, split (Task 1 & 2)

# %%
import os
import random
import numpy as np

SEED = 42
random.seed(SEED)
np.random.seed(SEED)

RAW_DIR = "/content/data/chest_xray"

def collect_all_images(raw_dir):
    filepaths, labels = [], []
    for split in ["train", "val", "test"]:
        for cls in ["NORMAL", "PNEUMONIA"]:
            folder = os.path.join(raw_dir, split, cls)
            if not os.path.isdir(folder):
                continue
            for fname in os.listdir(folder):
                if fname.lower().endswith((".jpeg", ".jpg", ".png")):
                    filepaths.append(os.path.join(folder, fname))
                    labels.append(cls)
    return filepaths, labels

filepaths, labels = collect_all_images(RAW_DIR)
print(f"Total images found: {len(filepaths)}")
print(f"NORMAL={labels.count('NORMAL')}, PNEUMONIA={labels.count('PNEUMONIA')}")
# Out:
# Total images found: 5856
# NORMAL=1583, PNEUMONIA=4273

# %%
import imagehash
from PIL import Image

def dedupe(filepaths, labels):
    seen_hashes = {}
    keep_paths, keep_labels = [], []
    for fp, lb in zip(filepaths, labels):
        try:
            h = str(imagehash.phash(Image.open(fp)))
        except Exception as e:
            print(f"Skipping corrupted file {fp}: {e}")
            continue
        if h in seen_hashes:
            continue
        seen_hashes[h] = fp
        keep_paths.append(fp)
        keep_labels.append(lb)
    print(f"Removed {len(filepaths) - len(keep_paths)} duplicate/corrupted images")
    return keep_paths, keep_labels

filepaths, labels = dedupe(filepaths, labels)
# Out:
# Removed 32 duplicate/corrupted images

# %%
from sklearn.model_selection import train_test_split

label_ids = [0 if l == "NORMAL" else 1 for l in labels]

train_fp, temp_fp, train_lb, temp_lb = train_test_split(
    filepaths, label_ids, test_size=0.2, stratify=label_ids, random_state=42)

val_fp, test_fp, val_lb, test_lb = train_test_split(
    temp_fp, temp_lb, test_size=0.5, stratify=temp_lb, random_state=42)

for name, lb in [("train", train_lb), ("val", val_lb), ("test", test_lb)]:
    print(f"{name}: total={len(lb)} NORMAL={lb.count(0)} PNEUMONIA={lb.count(1)}")
# Out:
# train: total=4659 NORMAL=1263 PNEUMONIA=3396
# val: total=582 NORMAL=158 PNEUMONIA=424
# test: total=583 NORMAL=158 PNEUMONIA=425

# %%
s_train, s_val, s_test = set(train_fp), set(val_fp), set(test_fp)
assert not (s_train & s_val), "Leakage between train/val!"
assert not (s_train & s_test), "Leakage between train/test!"
assert not (s_val & s_test), "Leakage between val/test!"
print("No leakage between splits confirmed.")
# Out:
# No leakage between splits confirmed.

# %%
import shutil

def materialize_split(fp_list, lb_list, out_root, split_name):
    for fp, lb in zip(fp_list, lb_list):
        cls_name = "NORMAL" if lb == 0 else "PNEUMONIA"
        dest_dir = os.path.join(out_root, split_name, cls_name)
        os.makedirs(dest_dir, exist_ok=True)
        shutil.copy(fp, os.path.join(dest_dir, os.path.basename(fp)))

OUT_ROOT = "/content/data_split"
materialize_split(train_fp, train_lb, OUT_ROOT, "train")
materialize_split(val_fp, val_lb, OUT_ROOT, "val")
materialize_split(test_fp, test_lb, OUT_ROOT, "test")
print(f"Split folders written to {OUT_ROOT}")
# Out:
# Split folders written to /content/data_split

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 4. Data pipeline — normalization & augmentation (Task 3)

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

IMG_SIZE = (150, 150)
BATCH_SIZE = 32
DATA_ROOT = "/content/data_split"

train_ds_raw = tf.keras.utils.image_dataset_from_directory(
    f"{DATA_ROOT}/train",
    labels="inferred",
    label_mode="binary",
    color_mode="grayscale",
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=True,
    seed=42
)
val_ds_raw = tf.keras.utils.image_dataset_from_directory(
    f"{DATA_ROOT}/val",
    labels="inferred",
    label_mode="binary",
    color_mode="grayscale",
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False
)
test_ds_raw = tf.keras.utils.image_dataset_from_directory(
    f"{DATA_ROOT}/test",
    labels="inferred",
    label_mode="binary",
    color_mode="grayscale",
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False
)

class_names = train_ds_raw.class_names
print("Classes:", class_names)

normalize = tf.keras.layers.Rescaling(1.0 / 255)
augment = tf.keras.Sequential([
    tf.keras.layers.RandomRotation(0.05),
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomZoom(0.1),
    tf.keras.layers.RandomTranslation(0.1, 0.1),
    tf.keras.layers.RandomBrightness(0.1),
])

def prep_train(image, label):
    image = normalize(image)
    image = augment(image, training=True)
    return image, label

def prep_eval(image, label):
    image = normalize(image)
    return image, label

AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds_raw.map(prep_train, num_parallel_calls=AUTOTUNE).cache().prefetch(AUTOTUNE)
val_ds = val_ds_raw.map(prep_eval, num_parallel_calls=AUTOTUNE).cache().prefetch(AUTOTUNE)
test_ds = test_ds_raw.map(prep_eval, num_parallel_calls=AUTOTUNE).cache().prefetch(AUTOTUNE)
print("Pipelines built.")
# Out:
# Found 4659 files belonging to 2 classes.
# Found 582 files belonging to 2 classes.
# Found 583 files belonging to 2 classes.
# Classes: ['NORMAL', 'PNEUMONIA']
# Pipelines built.

# %%
import numpy as np

train_labels_flat = np.concatenate([y.numpy() for _, y in train_ds_raw], axis=0).flatten()
n_normal = np.sum(train_labels_flat == 0)
n_pneumonia = np.sum(train_labels_flat == 1)
total = n_normal + n_pneumonia
class_weight = {0: total / (2 * n_normal), 1: total / (2 * n_pneumonia)}
print("Class weights:", class_weight)
# Out:
# Class weights: {0: np.float64(1.844418052256532), 1: np.float64(0.6859540636042403)}

# %%
def show_before_after(dataset_raw):
    for images, labels in dataset_raw.take(1):
        img = images[0]
        fig, axes = plt.subplots(1, 5, figsize=(15, 3))
        axes[0].imshow(img.numpy().astype("uint8").squeeze(), cmap="gray")
        axes[0].set_title("Original"); axes[0].axis("off")
        norm_img = normalize(tf.expand_dims(img, 0))
        for i in range(1, 5):
            aug_img = augment(norm_img, training=True)[0]
            axes[i].imshow(aug_img.numpy().squeeze(), cmap="gray")
            axes[i].set_title(f"Augmented {i}"); axes[i].axis("off")
        plt.tight_layout()
        plt.savefig("/content/augmentation_examples.png", dpi=150)
        plt.show()
show_before_after(train_ds_raw)

# %% [markdown]
# ## 5. Primary model — custom CNN (Task 4)

# %%
from tensorflow.keras import layers, models, regularizers

def build_custom_cnn(input_shape=(150, 150, 1), dropout_rate=0.5, l2_lambda=1e-4):
    inputs = layers.Input(shape=input_shape)

    x = layers.Conv2D(32, 3, padding="same", kernel_regularizer=regularizers.l2(l2_lambda))(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    x = layers.MaxPooling2D()(x)

    x = layers.Conv2D(64, 3, padding="same", kernel_regularizer=regularizers.l2(l2_lambda))(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    x = layers.MaxPooling2D()(x)

    x = layers.Conv2D(128, 3, padding="same", kernel_regularizer=regularizers.l2(l2_lambda))(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    x = layers.MaxPooling2D()(x)

    x = layers.Conv2D(256, 3, padding="same", kernel_regularizer=regularizers.l2(l2_lambda))(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    x = layers.MaxPooling2D()(x)

    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(128, activation="relu", kernel_regularizer=regularizers.l2(l2_lambda))(x)
    x = layers.Dropout(dropout_rate)(x)
    outputs = layers.Dense(1, activation="sigmoid")(x)

    return models.Model(inputs, outputs, name="custom_cnn")

model = build_custom_cnn()
model.summary()
# Out:
# Model: "custom_cnn"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_5 (InputLayer)      │ (None, 150, 150, 1)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_16 (Conv2D)              │ (None, 150, 150, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_16          │ (None, 150, 150, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_16 (ReLU)                 │ (None, 150, 150, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_16 (MaxPooling2D) │ (None, 75, 75, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_17 (Conv2D)              │ (None, 75, 75, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_17          │ (None, 75, 75, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_17 (ReLU)                 │ (None, 75, 75, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_17 (MaxPooling2D) │ (None, 37, 37, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_18 (Conv2D)              │ (None, 37, 37, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_18          │ (None, 37, 37, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_18 (ReLU)                 │ (None, 37, 37, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_18 (MaxPooling2D) │ (None, 18, 18, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_19 (Conv2D)              │ (None, 18, 18, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_19          │ (None, 18, 18, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_19 (ReLU)                 │ (None, 18, 18, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_19 (MaxPooling2D) │ (None, 9, 9, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_4      │ (None, 256)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 422,785 (1.61 MB)
#  Trainable params: 421,825 (1.61 MB)
#  Non-trainable params: 960 (3.75 KB)

# %%
import pandas as pd

rows = []
for layer in model.layers:
    out_shape = layer.output.shape if hasattr(layer, "output") else "N/A"
    rows.append({
        "Layer (name)": layer.name,
        "Type": layer.__class__.__name__,
        "Output Shape": str(out_shape),
        "Param #": f"{layer.count_params():,}"
    })

df = pd.DataFrame(rows)
print(df.to_string(index=False))
print(f"\nTotal params: {model.count_params():,}")
print(f"Trainable params: {sum(tf.keras.backend.count_params(w) for w in model.trainable_weights):,}")
# Out:
#               Layer (name)                   Type         Output Shape Param #
#              input_layer_5             InputLayer  (None, 150, 150, 1)       0
#                  conv2d_16                 Conv2D (None, 150, 150, 32)     320
#     batch_normalization_16     BatchNormalization (None, 150, 150, 32)     128
#                   re_lu_16                   ReLU (None, 150, 150, 32)       0
#           max_pooling2d_16           MaxPooling2D   (None, 75, 75, 32)       0
#                  conv2d_17                 Conv2D   (None, 75, 75, 64)  18,496
#     batch_normalization_17     BatchNormalization   (None, 75, 75, 64)     256
#                   re_lu_17                   ReLU   (None, 75, 75, 64)       0
#           max_pooling2d_17           MaxPooling2D   (None, 37, 37, 64)       0
#                  conv2d_18                 Conv2D  (None, 37, 37, 128)  73,856
#     batch_normalization_18     BatchNormalization  (None, 37, 37, 128)     512
#                   re_lu_18                   ReLU  (None, 37, 37, 128)       0
#           max_pooling2d_18           MaxPooling2D  (None, 18, 18, 128)       0
#                  conv2d_19                 Conv2D  (None, 18, 18, 256) 295,168
#     batch_normalization_19     BatchNormalization  (None, 18, 18, 256)   1,024
#                   re_lu_19                   ReLU  (None, 18, 18, 256)       0
#           max_pooling2d_19           MaxPooling2D    (None, 9, 9, 256)       0
# global_average_pooling2d_4 GlobalAveragePooling2D          (None, 256)       0
#                    dense_8                  Dense          (None, 128)  32,896
#                  dropout_4                Dropout          (None, 128)       0
#                    dense_9                  Dense            (None, 1)     129
#
# Total params: 422,785
# Trainable params: 421,825

# %% [markdown]
# ## 6. Training pipeline (Task 6)

# %%
import time
tf.random.set_seed(42)
run_id = time.strftime("%Y%m%d_%H%M%S")

model = build_custom_cnn()
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss="binary_crossentropy",
    metrics=["accuracy", tf.keras.metrics.AUC(name="auc")],
)
callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        f"/content/results/custom_cnn_{run_id}.keras",
        monitor="val_auc",
        mode="max",
        save_best_only=True,
        verbose=1),
    tf.keras.callbacks.EarlyStopping(
        monitor="val_auc",
        mode="max",
        patience=10,
        restore_best_weights=True,
        verbose=1),
    tf.keras.callbacks.CSVLogger(f"/content/results/history_{run_id}.csv"),
]

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=50,
    class_weight=class_weight,
    callbacks=callbacks,
)
# Out:
# Epoch 1/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.4998 - auc: 0.5153 - loss: 0.8033
# Epoch 1: val_auc improved from None to 0.50118, saving model to /content/results/custom_cnn_20260913_235417.keras
#
# Epoch 1: finished saving model to /content/results/custom_cnn_20260913_235417.keras
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 21s 86ms/step - accuracy: 0.5050 - auc: 0.5083 - loss: 0.7864 - val_accuracy: 0.2715 - val_auc: 0.5012 - val_loss: 0.7527
# Epoch 2/50
# 145/146 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.4765 - auc: 0.4823 - loss: 0.7713
# Epoch 2: val_auc improved from 0.50118 to 0.59116, saving model to /content/results/custom_cnn_20260913_235417.keras
#
# Epoch 2: finished saving model to /content/results/custom_cnn_20260913_235417.keras
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.4864 - auc: 0.4853 - loss: 0.7595 - val_accuracy: 0.2715 - val_auc: 0.5912 - val_loss: 0.7580
# Epoch 3/50
# 145/146 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.4933 - auc: 0.4959 - loss: 0.7571
# Epoch 3: val_auc did not improve from 0.59116
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.5014 - auc: 0.5033 - loss: 0.7477 - val_accuracy: 0.7285 - val_auc: 0.5590 - val_loss: 0.7301
# Epoch 4/50
# 145/146 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.4957 - auc: 0.5213 - loss: 0.7509
# Epoch 4: val_auc did not improve from 0.59116
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.4887 - auc: 0.5101 - loss: 0.7445 - val_accuracy: 0.2715 - val_auc: 0.5305 - val_loss: 0.7580
# Epoch 5/50
# 145/146 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.4867 - auc: 0.5030 - loss: 0.7508
# Epoch 5: val_auc improved from 0.59116 to 0.63461, saving model to /content/results/custom_cnn_20260913_235417.keras
#
# Epoch 5: finished saving model to /content/results/custom_cnn_20260913_235417.keras
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.4971 - auc: 0.4973 - loss: 0.7443 - val_accuracy: 0.2818 - val_auc: 0.6346 - val_loss: 0.7440
# Epoch 6/50
# 145/146 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5074 - auc: 0.5244 - loss: 0.7480
# Epoch 6: val_auc improved from 0.63461 to 0.71718, saving model to /content/results/custom_cnn_20260913_235417.keras
#
# Epoch 6: finished saving model to /content/results/custom_cnn_20260913_235417.keras
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.5162 - auc: 0.5134 - loss: 0.7411 - val_accuracy: 0.2749 - val_auc: 0.7172 - val_loss: 0.7535
# Epoch 7/50
# 145/146 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.4791 - auc: 0.4919 - loss: 0.7509
# Epoch 7: val_auc did not improve from 0.71718
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.4791 - auc: 0.4955 - loss: 0.7415 - val_accuracy: 0.7234 - val_auc: 0.7036 - val_loss: 0.7283
# Epoch 8/50
# 145/146 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.4998 - auc: 0.5202 - loss: 0.7467
# Epoch 8: val_auc improved from 0.71718 to 0.78634, saving model to /content/results/custom_cnn_20260913_235417.keras
#
# Epoch 8: finished saving model to /content/results/custom_cnn_20260913_235417.keras
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.5115 - auc: 0.5129 - loss: 0.7395 - val_accuracy: 0.4759 - val_auc: 0.7863 - val_loss: 0.7377
# Epoch 9/50
# 145/146 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.4995 - auc: 0.5173 - loss: 0.7457
# Epoch 9: val_auc did not improve from 0.78634
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.4965 - auc: 0.4990 - loss: 0.7399 - val_accuracy: 0.2715 - val_auc: 0.6659 - val_loss: 0.7499
# Epoch 10/50
# 145/146 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5254 - auc: 0.5183 - loss: 0.7463
# Epoch 10: val_auc did not improve from 0.78634
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.5098 - auc: 0.5095 - loss: 0.7388 - val_accuracy: 0.2715 - val_auc: 0.6696 - val_loss: 0.7617
# Epoch 11/50
# 145/146 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.4888 - auc: 0.4987 - loss: 0.7480
# Epoch 11: val_auc did not improve from 0.78634
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.4924 - auc: 0.5054 - loss: 0.7394 - val_accuracy: 0.6632 - val_auc: 0.7255 - val_loss: 0.7335
# Epoch 12/50
# 145/146 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.4870 - auc: 0.5191 - loss: 0.7450
# Epoch 12: val_auc did not improve from 0.78634
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.4904 - auc: 0.5154 - loss: 0.7372 - val_accuracy: 0.3677 - val_auc: 0.7191 - val_loss: 0.7400
# Epoch 13/50
# 145/146 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.4974 - auc: 0.5160 - loss: 0.7448
# Epoch 13: val_auc did not improve from 0.78634
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.5203 - auc: 0.5154 - loss: 0.7377 - val_accuracy: 0.7285 - val_auc: 0.4800 - val_loss: 0.7281
# Epoch 14/50
# 145/146 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5550 - auc: 0.5152 - loss: 0.7463
# Epoch 14: val_auc improved from 0.78634 to 0.87479, saving model to /content/results/custom_cnn_20260913_235417.keras
#
# Epoch 14: finished saving model to /content/results/custom_cnn_20260913_235417.keras
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.5649 - auc: 0.5099 - loss: 0.7383 - val_accuracy: 0.2715 - val_auc: 0.8748 - val_loss: 0.7512
# Epoch 15/50
# 145/146 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.4819 - auc: 0.4974 - loss: 0.7459
# Epoch 15: val_auc did not improve from 0.87479
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.5044 - auc: 0.5088 - loss: 0.7370 - val_accuracy: 0.4141 - val_auc: 0.7912 - val_loss: 0.7376
# Epoch 16/50
# 145/146 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5198 - auc: 0.5187 - loss: 0.7439
# Epoch 16: val_auc improved from 0.87479 to 0.88069, saving model to /content/results/custom_cnn_20260913_235417.keras
#
# Epoch 16: finished saving model to /content/results/custom_cnn_20260913_235417.keras
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.5334 - auc: 0.5171 - loss: 0.7362 - val_accuracy: 0.3076 - val_auc: 0.8807 - val_loss: 0.7385
# Epoch 17/50
# 145/146 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5299 - auc: 0.5144 - loss: 0.7447
# Epoch 17: val_auc did not improve from 0.88069
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.5259 - auc: 0.5157 - loss: 0.7361 - val_accuracy: 0.3024 - val_auc: 0.8589 - val_loss: 0.7393
# Epoch 18/50
# 145/146 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.4960 - auc: 0.5172 - loss: 0.7432
# Epoch 18: val_auc improved from 0.88069 to 0.89891, saving model to /content/results/custom_cnn_20260913_235417.keras
#
# Epoch 18: finished saving model to /content/results/custom_cnn_20260913_235417.keras
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.5055 - auc: 0.5146 - loss: 0.7353 - val_accuracy: 0.2715 - val_auc: 0.8989 - val_loss: 0.7695
# Epoch 19/50
# 145/146 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5205 - auc: 0.5124 - loss: 0.7448
# Epoch 19: val_auc did not improve from 0.89891
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.5254 - auc: 0.5093 - loss: 0.7359 - val_accuracy: 0.3797 - val_auc: 0.7684 - val_loss: 0.7370
# Epoch 20/50
# 145/146 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5043 - auc: 0.5219 - loss: 0.7422
# Epoch 20: val_auc did not improve from 0.89891
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.5203 - auc: 0.5147 - loss: 0.7345 - val_accuracy: 0.5172 - val_auc: 0.7273 - val_loss: 0.7342
# Epoch 21/50
# 145/146 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5263 - auc: 0.5145 - loss: 0.7422
# Epoch 21: val_auc did not improve from 0.89891
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.5375 - auc: 0.5159 - loss: 0.7342 - val_accuracy: 0.4467 - val_auc: 0.8835 - val_loss: 0.7330
# Epoch 22/50
# 145/146 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5507 - auc: 0.5040 - loss: 0.7427
# Epoch 22: val_auc improved from 0.89891 to 0.90446, saving model to /content/results/custom_cnn_20260913_235417.keras
#
# Epoch 22: finished saving model to /content/results/custom_cnn_20260913_235417.keras
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.5643 - auc: 0.5109 - loss: 0.7339 - val_accuracy: 0.3986 - val_auc: 0.9045 - val_loss: 0.7334
# Epoch 23/50
# 145/146 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5363 - auc: 0.5222 - loss: 0.7411
# Epoch 23: val_auc did not improve from 0.90446
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.5435 - auc: 0.5151 - loss: 0.7334 - val_accuracy: 0.4674 - val_auc: 0.8225 - val_loss: 0.7330
# Epoch 24/50
# 145/146 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5222 - auc: 0.5085 - loss: 0.7416
# Epoch 24: val_auc did not improve from 0.90446
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.5156 - auc: 0.5101 - loss: 0.7337 - val_accuracy: 0.6907 - val_auc: 0.7914 - val_loss: 0.7288
# Epoch 25/50
# 145/146 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.4916 - auc: 0.5210 - loss: 0.7405
# Epoch 25: val_auc did not improve from 0.90446
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.5327 - auc: 0.5176 - loss: 0.7328 - val_accuracy: 0.7698 - val_auc: 0.8842 - val_loss: 0.7164
# Epoch 26/50
# 145/146 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5603 - auc: 0.5304 - loss: 0.7395
# Epoch 26: val_auc did not improve from 0.90446
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.5375 - auc: 0.5206 - loss: 0.7316 - val_accuracy: 0.2715 - val_auc: 0.7875 - val_loss: 0.7614
# Epoch 27/50
# 145/146 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5081 - auc: 0.5259 - loss: 0.7401
# Epoch 27: val_auc did not improve from 0.90446
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.5381 - auc: 0.5254 - loss: 0.7320 - val_accuracy: 0.7337 - val_auc: 0.7692 - val_loss: 0.7243
# Epoch 28/50
# 145/146 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5347 - auc: 0.5207 - loss: 0.7398
# Epoch 28: val_auc did not improve from 0.90446
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.5377 - auc: 0.5089 - loss: 0.7320 - val_accuracy: 0.3488 - val_auc: 0.8079 - val_loss: 0.7340
# Epoch 29/50
# 145/146 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5350 - auc: 0.5138 - loss: 0.7394
# Epoch 29: val_auc did not improve from 0.90446
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.5510 - auc: 0.5214 - loss: 0.7304 - val_accuracy: 0.3540 - val_auc: 0.7878 - val_loss: 0.7361
# Epoch 30/50
# 145/146 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.4769 - auc: 0.5149 - loss: 0.7383
# Epoch 30: val_auc improved from 0.90446 to 0.90578, saving model to /content/results/custom_cnn_20260913_235417.keras
#
# Epoch 30: finished saving model to /content/results/custom_cnn_20260913_235417.keras
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.5031 - auc: 0.5128 - loss: 0.7307 - val_accuracy: 0.2766 - val_auc: 0.9058 - val_loss: 0.7408
# Epoch 31/50
# 145/146 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5249 - auc: 0.5200 - loss: 0.7367
# Epoch 31: val_auc improved from 0.90578 to 0.91207, saving model to /content/results/custom_cnn_20260913_235417.keras
#
# Epoch 31: finished saving model to /content/results/custom_cnn_20260913_235417.keras
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 10s 35ms/step - accuracy: 0.5336 - auc: 0.5203 - loss: 0.7289 - val_accuracy: 0.2869 - val_auc: 0.9121 - val_loss: 0.7402
# Epoch 32/50
# 145/146 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5456 - auc: 0.5266 - loss: 0.7364
# Epoch 32: val_auc did not improve from 0.91207
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.5428 - auc: 0.5174 - loss: 0.7290 - val_accuracy: 0.2715 - val_auc: 0.9036 - val_loss: 0.7538
# Epoch 33/50
# 145/146 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5316 - auc: 0.5100 - loss: 0.7378
# Epoch 33: val_auc did not improve from 0.91207
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.5400 - auc: 0.5124 - loss: 0.7295 - val_accuracy: 0.3024 - val_auc: 0.9086 - val_loss: 0.7328
# Epoch 34/50
# 145/146 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5509 - auc: 0.5328 - loss: 0.7349
# Epoch 34: val_auc improved from 0.91207 to 0.91349, saving model to /content/results/custom_cnn_20260913_235417.keras
#
# Epoch 34: finished saving model to /content/results/custom_cnn_20260913_235417.keras
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.5475 - auc: 0.5291 - loss: 0.7270 - val_accuracy: 0.2715 - val_auc: 0.9135 - val_loss: 0.7531
# Epoch 35/50
# 145/146 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5061 - auc: 0.5256 - loss: 0.7348
# Epoch 35: val_auc did not improve from 0.91349
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.5029 - auc: 0.5238 - loss: 0.7269 - val_accuracy: 0.3866 - val_auc: 0.9104 - val_loss: 0.7273
# Epoch 36/50
# 145/146 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5096 - auc: 0.5210 - loss: 0.7350
# Epoch 36: val_auc did not improve from 0.91349
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.5160 - auc: 0.5142 - loss: 0.7273 - val_accuracy: 0.2749 - val_auc: 0.9125 - val_loss: 0.7403
# Epoch 37/50
# 145/146 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5094 - auc: 0.5534 - loss: 0.7301
# Epoch 37: val_auc did not improve from 0.91349
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.5291 - auc: 0.5424 - loss: 0.7236 - val_accuracy: 0.2732 - val_auc: 0.9102 - val_loss: 0.7562
# Epoch 38/50
# 145/146 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5325 - auc: 0.5234 - loss: 0.7331
# Epoch 38: val_auc did not improve from 0.91349
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.5490 - auc: 0.5315 - loss: 0.7235 - val_accuracy: 0.2938 - val_auc: 0.9123 - val_loss: 0.7616
# Epoch 39/50
# 145/146 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5161 - auc: 0.5410 - loss: 0.7304
# Epoch 39: val_auc improved from 0.91349 to 0.91383, saving model to /content/results/custom_cnn_20260913_235417.keras
#
# Epoch 39: finished saving model to /content/results/custom_cnn_20260913_235417.keras
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.5353 - auc: 0.5446 - loss: 0.7219 - val_accuracy: 0.2715 - val_auc: 0.9138 - val_loss: 1.1296
# Epoch 40/50
# 145/146 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5210 - auc: 0.5553 - loss: 0.7269
# Epoch 40: val_auc did not improve from 0.91383
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.5555 - auc: 0.5555 - loss: 0.7198 - val_accuracy: 0.7320 - val_auc: 0.7733 - val_loss: 0.7123
# Epoch 41/50
# 145/146 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5557 - auc: 0.5647 - loss: 0.7238
# Epoch 41: val_auc did not improve from 0.91383
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.5686 - auc: 0.5706 - loss: 0.7139 - val_accuracy: 0.8162 - val_auc: 0.8402 - val_loss: 0.7103
# Epoch 42/50
# 145/146 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5425 - auc: 0.5597 - loss: 0.7250
# Epoch 42: val_auc did not improve from 0.91383
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.5632 - auc: 0.5787 - loss: 0.7120 - val_accuracy: 0.2766 - val_auc: 0.7615 - val_loss: 0.7342
# Epoch 43/50
# 145/146 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5770 - auc: 0.5965 - loss: 0.7126
# Epoch 43: val_auc did not improve from 0.91383
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.5948 - auc: 0.6289 - loss: 0.6943 - val_accuracy: 0.2715 - val_auc: 0.8721 - val_loss: 0.7407
# Epoch 44/50
# 145/146 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5807 - auc: 0.6262 - loss: 0.7051
# Epoch 44: val_auc did not improve from 0.91383
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.6152 - auc: 0.6510 - loss: 0.6872 - val_accuracy: 0.7887 - val_auc: 0.8904 - val_loss: 0.6978
# Epoch 45/50
# 145/146 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.6332 - auc: 0.6866 - loss: 0.6664
# Epoch 45: val_auc did not improve from 0.91383
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.6495 - auc: 0.6917 - loss: 0.6583 - val_accuracy: 0.4175 - val_auc: 0.9055 - val_loss: 0.7154
# Epoch 46/50
# 145/146 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6360 - auc: 0.6987 - loss: 0.6555
# Epoch 46: val_auc improved from 0.91383 to 0.91440, saving model to /content/results/custom_cnn_20260913_235417.keras
#
# Epoch 46: finished saving model to /content/results/custom_cnn_20260913_235417.keras
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.6570 - auc: 0.7122 - loss: 0.6405 - val_accuracy: 0.2801 - val_auc: 0.9144 - val_loss: 0.7374
# Epoch 47/50
# 145/146 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.6359 - auc: 0.7073 - loss: 0.6415
# Epoch 47: val_auc did not improve from 0.91440
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.6519 - auc: 0.7175 - loss: 0.6294 - val_accuracy: 0.8265 - val_auc: 0.8747 - val_loss: 0.6783
# Epoch 48/50
# 145/146 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.6022 - auc: 0.6966 - loss: 0.6574
# Epoch 48: val_auc improved from 0.91440 to 0.91856, saving model to /content/results/custom_cnn_20260913_235417.keras
#
# Epoch 48: finished saving model to /content/results/custom_cnn_20260913_235417.keras
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.6450 - auc: 0.7224 - loss: 0.6228 - val_accuracy: 0.4330 - val_auc: 0.9186 - val_loss: 0.7108
# Epoch 49/50
# 145/146 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6157 - auc: 0.7170 - loss: 0.6277
# Epoch 49: val_auc did not improve from 0.91856
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.6420 - auc: 0.7342 - loss: 0.6117 - val_accuracy: 0.3522 - val_auc: 0.9019 - val_loss: 0.7186
# Epoch 50/50
# 145/146 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.6196 - auc: 0.7356 - loss: 0.6128
# Epoch 50: val_auc did not improve from 0.91856
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.6278 - auc: 0.7424 - loss: 0.6023 - val_accuracy: 0.7680 - val_auc: 0.7371 - val_loss: 0.6422
# Restoring model weights from the end of the best epoch: 48.

# %%
import matplotlib.pyplot as plt
import os

os.makedirs("/content/results", exist_ok=True)
best_epoch = int(np.argmax(history.history["val_auc"]))

fig, axes = plt.subplots(1, 3, figsize=(16, 4))

axes[0].plot(history.history["loss"], label="train")
axes[0].plot(history.history["val_loss"], label="val")
axes[0].axvline(best_epoch, color="gray", linestyle="--", label=f"best epoch ({best_epoch})")
axes[0].set_title("custom_cnn: Loss"); axes[0].set_xlabel("Epoch"); axes[0].legend()

axes[1].plot(history.history["auc"], label="train")
axes[1].plot(history.history["val_auc"], label="val")
axes[1].axvline(best_epoch, color="gray", linestyle="--")
axes[1].set_title("custom_cnn: AUC"); axes[1].set_xlabel("Epoch"); axes[1].legend()

axes[2].plot(history.history["accuracy"], label="train")
axes[2].plot(history.history["val_accuracy"], label="val")
axes[2].axvline(best_epoch, color="gray", linestyle="--")
axes[2].set_title("custom_cnn: Accuracy"); axes[2].set_xlabel("Epoch"); axes[2].legend()

plt.tight_layout()
plt.savefig(f"/content/results/custom_cnn_curves_{run_id}.png", dpi=150)
plt.show()

print(f"Best epoch: {best_epoch}, val_auc: {history.history['val_auc'][best_epoch]:.4f}")
# Out:
# Best epoch: 47, val_auc: 0.9186

# %% [markdown]
# ## 7. Model diagnostics — threshold & calibration check

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, f1_score

def get_labels_and_probs(model, dataset):
    y_true, y_prob = [], []
    for images, labels in dataset:
        probs = model.predict(images, verbose=0).flatten()
        y_prob.extend(probs)
        y_true.extend(labels.numpy().flatten())
    return np.array(y_true), np.array(y_prob)

y_val_true, y_val_prob = get_labels_and_probs(model, val_ds)

plt.figure(figsize=(6, 4))
plt.hist(y_val_prob[y_val_true == 0], bins=30, alpha=0.6, label="NORMAL (true)")
plt.hist(y_val_prob[y_val_true == 1], bins=30, alpha=0.6, label="PNEUMONIA (true)")
plt.xlabel("Predicted probability of PNEUMONIA")
plt.ylabel("Count")
plt.legend()
plt.title("Validation prediction distribution")
plt.savefig("/content/results/custom_cnn_prob_histogram.png", dpi=150)
plt.show()

thresholds = np.linspace(0.01, 0.99, 99)
f1_scores = [f1_score(y_val_true, (y_val_prob >= t).astype(int)) for t in thresholds]
CUSTOM_CNN_THRESHOLD = thresholds[np.argmax(f1_scores)]
print(f"Best threshold (max F1 on val): {CUSTOM_CNN_THRESHOLD:.2f}")

for label, t in [("0.50 (default)", 0.5), (f"{CUSTOM_CNN_THRESHOLD:.2f} (optimal)", CUSTOM_CNN_THRESHOLD)]:
    preds = (y_val_prob >= t).astype(int)
    print(f"\n--- Threshold {label} ---")
    print(confusion_matrix(y_val_true, preds))
    print(classification_report(y_val_true, preds, target_names=class_names))
# Out:
# Best threshold (max F1 on val): 0.42
#
# --- Threshold 0.50 (default) ---
# [[158   0]
#  [330  94]]
#               precision    recall  f1-score   support
#
#       NORMAL       0.32      1.00      0.49       158
#    PNEUMONIA       1.00      0.22      0.36       424
#
#     accuracy                           0.43       582
#    macro avg       0.66      0.61      0.43       582
# weighted avg       0.82      0.43      0.40       582
#
#
# --- Threshold 0.42 (optimal) ---
# [[121  37]
#  [ 42 382]]
#               precision    recall  f1-score   support
#
#       NORMAL       0.74      0.77      0.75       158
#    PNEUMONIA       0.91      0.90      0.91       424
#
#     accuracy                           0.86       582
#    macro avg       0.83      0.83      0.83       582
# weighted avg       0.87      0.86      0.86       582

# %%
import shutil
import os

# Ensure the results directory exists, though it should from previous steps
os.makedirs("/content/results", exist_ok=True)

# Copy the best performing model to the final name
shutil.copy(f"/content/results/custom_cnn_{run_id}.keras", "/content/results/custom_cnn_FINAL.keras")

print(f"Copied /content/results/custom_cnn_{run_id}.keras to /content/results/custom_cnn_FINAL.keras")
# Out:
# Copied /content/results/custom_cnn_20260913_235417.keras to /content/results/custom_cnn_FINAL.keras

# %% [markdown]
# ## 8. Comparison models — VGG16 & ResNet50, frozen and fine-tuned (Task 5)

# %%
from tensorflow.keras.applications import VGG16, ResNet50
from tensorflow.keras.applications.vgg16 import preprocess_input as vgg_preprocess
from tensorflow.keras.applications.resnet50 import preprocess_input as resnet_preprocess

PRETRAINED_IMG_SIZE = (224, 224)

def make_pretrained_datasets(preprocess_fn):
    train_raw = tf.keras.utils.image_dataset_from_directory(
        f"{DATA_ROOT}/train", labels="inferred", label_mode="binary",
        color_mode="rgb", image_size=PRETRAINED_IMG_SIZE, batch_size=BATCH_SIZE,
        shuffle=True, seed=42)
    val_raw = tf.keras.utils.image_dataset_from_directory(
        f"{DATA_ROOT}/val", labels="inferred", label_mode="binary",
        color_mode="rgb", image_size=PRETRAINED_IMG_SIZE, batch_size=BATCH_SIZE, shuffle=False)
    test_raw = tf.keras.utils.image_dataset_from_directory(
        f"{DATA_ROOT}/test", labels="inferred", label_mode="binary",
        color_mode="rgb", image_size=PRETRAINED_IMG_SIZE, batch_size=BATCH_SIZE, shuffle=False)

    def prep_train_pt(image, label):
        image = augment(image, training=True)
        image = preprocess_fn(image)
        return image, label

    def prep_eval_pt(image, label):
        return preprocess_fn(image), label

    train = train_raw.map(prep_train_pt, num_parallel_calls=AUTOTUNE).prefetch(AUTOTUNE)
    val = val_raw.map(prep_eval_pt, num_parallel_calls=AUTOTUNE).prefetch(AUTOTUNE)
    test = test_raw.map(prep_eval_pt, num_parallel_calls=AUTOTUNE).prefetch(AUTOTUNE)
    return train, val, test

def build_transfer_model(base_class, name, trainable=False, fine_tune_at=None, dropout_rate=0.5):
    base = base_class(include_top=False, weights="imagenet", input_shape=(224, 224, 3))
    base.trainable = trainable
    if trainable and fine_tune_at is not None:
        for layer in base.layers[:fine_tune_at]:
            layer.trainable = False

    inputs = layers.Input(shape=(224, 224, 3))
    x = base(inputs, training=trainable)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(128, activation="relu")(x)
    x = layers.Dropout(dropout_rate)(x)
    outputs = layers.Dense(1, activation="sigmoid")(x)
    return models.Model(inputs, outputs, name=name)

def train_variant(m, train_ds_var, val_ds_var, name, epochs=15, lr=1e-4, patience=5):
    m.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
        loss="binary_crossentropy",
        metrics=["accuracy", tf.keras.metrics.AUC(name="auc")]
    )
    cb = [
        tf.keras.callbacks.ModelCheckpoint(f"/content/results/{name}_best.keras", monitor="val_auc",
                                            mode="max", save_best_only=True, verbose=0),
        tf.keras.callbacks.EarlyStopping(monitor="val_auc", mode="max", patience=patience,
                                          restore_best_weights=True, verbose=1),
    ]
    return m.fit(train_ds_var, validation_data=val_ds_var, epochs=epochs,
                 class_weight=class_weight, callbacks=cb, verbose=1)

transfer_histories = {}

# %%
# VGG16 - frozen backbone (feature extraction only)
train_vgg, val_vgg, test_vgg = make_pretrained_datasets(vgg_preprocess)

vgg_frozen = build_transfer_model(VGG16, "vgg16_frozen", trainable=False)
transfer_histories["vgg16_frozen"] = train_variant(vgg_frozen, train_vgg, val_vgg, "vgg16_frozen", epochs=15, lr=1e-3)
# Out:
# Found 4659 files belonging to 2 classes.
# Found 582 files belonging to 2 classes.
# Found 583 files belonging to 2 classes.
# Epoch 1/15
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 107s 680ms/step - accuracy: 0.8339 - auc: 0.9019 - loss: 0.4541 - val_accuracy: 0.8265 - val_auc: 0.9711 - val_loss: 0.4530
# Epoch 2/15
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 137s 687ms/step - accuracy: 0.8978 - auc: 0.9606 - loss: 0.2546 - val_accuracy: 0.9175 - val_auc: 0.9715 - val_loss: 0.2664
# Epoch 3/15
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 139s 670ms/step - accuracy: 0.9066 - auc: 0.9669 - loss: 0.2336 - val_accuracy: 0.9021 - val_auc: 0.9735 - val_loss: 0.2975
# Epoch 4/15
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 95s 644ms/step - accuracy: 0.9163 - auc: 0.9736 - loss: 0.2084 - val_accuracy: 0.9055 - val_auc: 0.9772 - val_loss: 0.2566
# Epoch 5/15
#  37/146 ━━━━━━━━━━━━━━━━━━━━ 1:15 692ms/step - accuracy: 0.9320 - auc: 0.9851 - loss: 0.1640

# %%
# VGG16 - fine-tuned (unfreeze the last few conv blocks, train at a low LR)
vgg_finetune = build_transfer_model(VGG16, "vgg16_finetuned", trainable=True, fine_tune_at=15)
transfer_histories["vgg16_finetuned"] = train_variant(vgg_finetune, train_vgg, val_vgg, "vgg16_finetuned", epochs=10, lr=1e-5)

# %%
# ResNet50 - frozen backbone
train_resnet, val_resnet, test_resnet = make_pretrained_datasets(resnet_preprocess)

resnet_frozen = build_transfer_model(ResNet50, "resnet50_frozen", trainable=False)
transfer_histories["resnet50_frozen"] = train_variant(resnet_frozen, train_resnet, val_resnet, "resnet50_frozen", epochs=15, lr=1e-3)

# %%
# ResNet50 - fine-tuned (unfreeze roughly the last third of layers)
resnet_finetune = build_transfer_model(ResNet50, "resnet50_finetuned", trainable=True, fine_tune_at=140)
transfer_histories["resnet50_finetuned"] = train_variant(resnet_finetune, train_resnet, val_resnet, "resnet50_finetuned", epochs=10, lr=1e-5)

# %%
# Plot training/validation curves for all 4 comparison models
fig, axes = plt.subplots(2, 2, figsize=(12, 8))
for ax, (name, h) in zip(axes.flat, transfer_histories.items()):
    ax.plot(h.history["val_auc"], label="val_auc")
    ax.plot(h.history["auc"], label="train_auc")
    ax.set_title(name)
    ax.set_xlabel("Epoch")
    ax.legend()
plt.tight_layout()
plt.savefig("/content/results/transfer_models_curves.png", dpi=150)
plt.show()

# %% [markdown]
# ## 9. Hyperparameter tuning & data-volume study (Task 7)
#
# **Scope note for the report:** a full cross-product grid search over all 8 requested hyperparameters (batch size, LR, epochs, dropout, patience, L1/L2, normalization, augmentation policy) would require thousands of training runs, which isn't feasible on Colab's free tier in the assignment timeframe. The approach below grid-searches the 4 hyperparameters with the largest expected effect (batch size, learning rate, dropout, L2 lambda) jointly, then tests normalization scheme, augmentation policy, and early-stopping patience as one-factor-at-a-time ablations on top of the best config found. State this scope decision explicitly in Section IV of the report.

# %%
import itertools
import pandas as pd

grid = {
    "batch_size": [16, 32],
    "learning_rate": [1e-3, 1e-4],
    "dropout_rate": [0.3, 0.5],
    "l2_lambda": [1e-4, 1e-3],
}

grid_results = []
combos = list(itertools.product(*grid.values()))
GRID_EPOCHS = 6
print(f"Running {len(combos)} grid search combinations ({GRID_EPOCHS} epochs each)...")

for bs, lr, dr, l2 in combos:
    tr_ds = train_ds_raw.unbatch().batch(bs).map(prep_train, num_parallel_calls=AUTOTUNE).prefetch(AUTOTUNE)
    va_ds = val_ds_raw.unbatch().batch(bs).map(prep_eval, num_parallel_calls=AUTOTUNE).prefetch(AUTOTUNE)

    m = build_custom_cnn(dropout_rate=dr, l2_lambda=l2)
    m.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr), loss="binary_crossentropy",
              metrics=["accuracy", tf.keras.metrics.AUC(name="auc")])
    h = m.fit(tr_ds, validation_data=va_ds, epochs=GRID_EPOCHS, class_weight=class_weight, verbose=0)
    best_val_auc = max(h.history["val_auc"])
    grid_results.append({"batch_size": bs, "learning_rate": lr, "dropout_rate": dr,
                          "l2_lambda": l2, "best_val_auc": best_val_auc})
    print(f"bs={bs}, lr={lr}, dropout={dr}, l2={l2} -> val_auc={best_val_auc:.4f}")

grid_df = pd.DataFrame(grid_results).sort_values("best_val_auc", ascending=False)
print("\n", grid_df.to_string(index=False))
grid_df.to_csv("/content/results/grid_search_results.csv", index=False)

best_config = grid_df.iloc[0].to_dict()
print("\nBest configuration:", best_config)

# %%
# Ablation: normalization scheme (0-1 rescale vs. per-image standardization) and augmentation on/off,
# using the best hyperparameters found above.

def make_ablation_ds(use_std_norm, use_augmentation):
    def _norm(image):
        return tf.image.per_image_standardization(image) if use_std_norm else normalize(image)

    def _prep_train(image, label):
        image = _norm(image)
        if use_augmentation:
            image = augment(image, training=True)
        return image, label

    def _prep_eval(image, label):
        return _norm(image), label

    tr = train_ds_raw.map(_prep_train, num_parallel_calls=AUTOTUNE).prefetch(AUTOTUNE)
    va = val_ds_raw.map(_prep_eval, num_parallel_calls=AUTOTUNE).prefetch(AUTOTUNE)
    return tr, va

ablation_results = []
for use_std_norm in [False, True]:
    for use_aug in [False, True]:
        tr, va = make_ablation_ds(use_std_norm, use_aug)
        m = build_custom_cnn(dropout_rate=best_config["dropout_rate"], l2_lambda=best_config["l2_lambda"])
        m.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=best_config["learning_rate"]),
                  loss="binary_crossentropy", metrics=["accuracy", tf.keras.metrics.AUC(name="auc")])
        h = m.fit(tr, validation_data=va, epochs=6, class_weight=class_weight, verbose=0)
        ablation_results.append({
            "normalization": "standardization" if use_std_norm else "rescale_0_1",
            "augmentation": use_aug,
            "best_val_auc": max(h.history["val_auc"])
        })
        print(ablation_results[-1])

ablation_df = pd.DataFrame(ablation_results)
ablation_df.to_csv("/content/results/ablation_results.csv", index=False)
print("\n", ablation_df.to_string(index=False))

# %%
# Ablation: early-stopping patience, using the best hyperparameters, on the real (150x150) pipeline
patience_results = []
for patience in [5, 10, 15]:
    m = build_custom_cnn(dropout_rate=best_config["dropout_rate"], l2_lambda=best_config["l2_lambda"])
    m.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=best_config["learning_rate"]),
              loss="binary_crossentropy", metrics=["accuracy", tf.keras.metrics.AUC(name="auc")])
    cb = [tf.keras.callbacks.EarlyStopping(monitor="val_auc", mode="max", patience=patience,
                                            restore_best_weights=True, verbose=0)]
    h = m.fit(train_ds, validation_data=val_ds, epochs=50, class_weight=class_weight, callbacks=cb, verbose=0)
    patience_results.append({"patience": patience, "epochs_run": len(h.history["loss"]),
                              "best_val_auc": max(h.history["val_auc"])})
    print(patience_results[-1])

patience_df = pd.DataFrame(patience_results)
patience_df.to_csv("/content/results/patience_ablation.csv", index=False)
print("\n", patience_df.to_string(index=False))

# %%
# Data-volume study: retrain on 25/50/75/100% of the training data
data_fractions = [0.25, 0.5, 0.75, 1.0]
volume_results = []
n_train_total = len(train_fp)

for frac in data_fractions:
    n_subset = int(n_train_total * frac)
    sub_fp, sub_lb = train_fp[:n_subset], train_lb[:n_subset]

    subset_root = f"/content/data_split_subset_{int(frac*100)}"
    materialize_split(sub_fp, sub_lb, subset_root, "train")

    sub_train_raw = tf.keras.utils.image_dataset_from_directory(
        f"{subset_root}/train", labels="inferred", label_mode="binary",
        color_mode="grayscale", image_size=IMG_SIZE, batch_size=BATCH_SIZE, shuffle=True, seed=42)
    sub_train_ds = sub_train_raw.map(prep_train, num_parallel_calls=AUTOTUNE).prefetch(AUTOTUNE)

    m = build_custom_cnn(dropout_rate=best_config["dropout_rate"], l2_lambda=best_config["l2_lambda"])
    m.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=best_config["learning_rate"]),
              loss="binary_crossentropy", metrics=["accuracy", tf.keras.metrics.AUC(name="auc")])
    cb = [tf.keras.callbacks.EarlyStopping(monitor="val_auc", mode="max", patience=8,
                                            restore_best_weights=True, verbose=0)]
    h = m.fit(sub_train_ds, validation_data=val_ds, epochs=30, class_weight=class_weight, callbacks=cb, verbose=0)

    volume_results.append({"data_fraction": frac, "n_train_images": n_subset,
                            "best_val_auc": max(h.history["val_auc"])})
    print(volume_results[-1])

volume_df = pd.DataFrame(volume_results)
volume_df.to_csv("/content/results/data_volume_results.csv", index=False)

plt.figure(figsize=(6, 4))
plt.plot(volume_df["data_fraction"] * 100, volume_df["best_val_auc"], marker="o")
plt.xlabel("Percent of training data used")
plt.ylabel("Best validation AUC")
plt.title("Performance vs. training data volume")
plt.savefig("/content/results/data_volume_curve.png", dpi=150)
plt.show()

# %% [markdown]
# ## 10. Evaluation across all models (Task 8)

# %%
def evaluate_model_on_test(m, dataset, threshold=0.5):
    y_true, y_prob = get_labels_and_probs(m, dataset)
    y_pred = (y_prob >= threshold).astype(int)
    report = classification_report(y_true, y_pred, target_names=class_names, output_dict=True)
    auc_score = roc_auc_score(y_true, y_prob)
    cm = confusion_matrix(y_true, y_pred)
    return {
        "accuracy": report["accuracy"],
        "precision_macro": report["macro avg"]["precision"],
        "recall_macro": report["macro avg"]["recall"],
        "f1_macro": report["macro avg"]["f1-score"],
        "auc": auc_score,
        "confusion_matrix": cm,
        "y_true": y_true,
        "y_prob": y_prob,
    }

all_models_eval = {
    "custom_cnn": evaluate_model_on_test(model, test_ds, threshold=CUSTOM_CNN_THRESHOLD),
    "vgg16_frozen": evaluate_model_on_test(vgg_frozen, test_vgg),
    "vgg16_finetuned": evaluate_model_on_test(vgg_finetune, test_vgg),
    "resnet50_frozen": evaluate_model_on_test(resnet_frozen, test_resnet),
    "resnet50_finetuned": evaluate_model_on_test(resnet_finetune, test_resnet),
}

comparison_rows = [{
    "Model": name,
    "Accuracy": round(res["accuracy"], 4),
    "Precision (macro)": round(res["precision_macro"], 4),
    "Recall (macro)": round(res["recall_macro"], 4),
    "F1 (macro)": round(res["f1_macro"], 4),
    "AUC": round(res["auc"], 4),
} for name, res in all_models_eval.items()]

comparison_df = pd.DataFrame(comparison_rows).sort_values("AUC", ascending=False)
comparison_df.to_csv("/content/results/model_comparison.csv", index=False)
print(comparison_df.to_string(index=False))

# %%
# ROC curves - all models on one plot
plt.figure(figsize=(7, 6))
for name, res in all_models_eval.items():
    fpr, tpr, _ = roc_curve(res["y_true"], res["y_prob"])
    plt.plot(fpr, tpr, label=f"{name} (AUC={res['auc']:.3f})")
plt.plot([0, 1], [0, 1], "k--", alpha=0.5)
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curves - All Models")
plt.legend()
plt.savefig("/content/results/roc_curves_all_models.png", dpi=150)
plt.show()

# %%
# Confusion matrix heatmap for the best-performing model
best_model_name = comparison_df.iloc[0]["Model"]
best_cm = all_models_eval[best_model_name]["confusion_matrix"]

plt.figure(figsize=(5, 4))
plt.imshow(best_cm, cmap="Blues")
plt.colorbar()
plt.xticks([0, 1], class_names)
plt.yticks([0, 1], class_names)
for i in range(2):
    for j in range(2):
        plt.text(j, i, best_cm[i, j], ha="center", va="center",
                  color="white" if best_cm[i, j] > best_cm.max() / 2 else "black")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title(f"Confusion Matrix - {best_model_name}")
plt.tight_layout()
plt.savefig("/content/results/confusion_matrix_best_model.png", dpi=150)
plt.show()

# %%
# Sample predictions grid (correct AND incorrect, color-coded)
def show_sample_predictions(m, dataset, threshold=0.5, n=12):
    images, labels = next(iter(dataset))
    probs = m.predict(images, verbose=0).flatten()
    preds = (probs >= threshold).astype(int)

    plt.figure(figsize=(14, 10))
    for i in range(min(n, len(images))):
        ax = plt.subplot(3, 4, i + 1)
        img = images[i].numpy()
        if img.shape[-1] == 1:
            plt.imshow(img.squeeze(), cmap="gray")
        else:
            disp = img - img.min()
            disp = disp / (disp.max() + 1e-8)
            plt.imshow(disp)
        true_lb = int(labels[i].numpy()[0])
        pred_lb = preds[i]
        color = "green" if true_lb == pred_lb else "red"
        plt.title(f"True: {class_names[true_lb]}\nPred: {class_names[pred_lb]} ({probs[i]:.2f})",
                   color=color, fontsize=9)
        plt.axis("off")
    plt.tight_layout()
    plt.savefig("/content/results/sample_predictions.png", dpi=150)
    plt.show()

show_sample_predictions(model, test_ds, threshold=CUSTOM_CNN_THRESHOLD)

# %% [markdown]
# ## 11. Error analysis (Task 9)

# %%
def get_misclassified(m, dataset, threshold=0.5, max_images=20):
    misclassified = []
    for images, labels in dataset:
        probs = m.predict(images, verbose=0).flatten()
        preds = (probs >= threshold).astype(int)
        true_lb = labels.numpy().flatten().astype(int)
        for i in range(len(true_lb)):
            if preds[i] != true_lb[i]:
                misclassified.append((images[i].numpy(), true_lb[i], preds[i], probs[i]))
            if len(misclassified) >= max_images:
                return misclassified
    return misclassified

misclassified_samples = get_misclassified(model, test_ds, threshold=CUSTOM_CNN_THRESHOLD, max_images=12)
print(f"Found {len(misclassified_samples)} misclassified samples shown below (need >=10 for Task 9)")

plt.figure(figsize=(14, 10))
for i, (img, true_lb, pred_lb, prob) in enumerate(misclassified_samples):
    ax = plt.subplot(3, 4, i + 1)
    plt.imshow(img.squeeze(), cmap="gray")
    plt.title(f"True: {class_names[true_lb]}\nPred: {class_names[pred_lb]} ({prob:.2f})", fontsize=9)
    plt.axis("off")
plt.tight_layout()
plt.savefig("/content/results/misclassified_examples.png", dpi=150)
plt.show()

# %% [markdown]
# **For each misclassified image above, note in your report:**
# - Was the true label NORMAL predicted as PNEUMONIA (false positive), or vice versa (false negative)?
# - Was the model's probability close to the threshold (uncertain) or confidently wrong?
# - Any visible reason: low contrast, unusual positioning, artifacts (tubes/wires), partial view?
# - Do false negatives or false positives dominate — and what does that imply clinically (missing pneumonia is usually worse than a false alarm)?

# %% [markdown]
# ## 12. Save all artifacts to Drive

# %%
import shutil, os

save_dir = "/content/drive/MyDrive/genai_assignment"
os.makedirs(f"{save_dir}/results", exist_ok=True)

for fname in os.listdir("/content/results"):
    shutil.copy(f"/content/results/{fname}", f"{save_dir}/results/{fname}")

if os.path.exists("/content/augmentation_examples.png"):
    shutil.copy("/content/augmentation_examples.png", save_dir)

print("Saved to Drive:", sorted(os.listdir(f"{save_dir}/results")))
